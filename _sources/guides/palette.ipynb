# %% [markdown]
# # Guide to palette.py module
# The function `plot_palette` accepts the arguments for the palette and returns a figure with a given palette.

# %%
from randomly.palette import  plot_palette
fig = plot_palette("default")
fig
